# %% [markdown]
# # Tokenization -part 1

# %% [markdown]
# * In this part we will discuss and demonsrate the application of various tokenization methods available such as split function, nltk library, and regular expression.
# * The goal is to justify the most suitable tokenization methods by comparing the performance of several methods.
# * We will also demonstrate stop words removal and report the output.
# * A proper checking mechanism will also be given for such scenarios

# %% [markdown]
# ## 1. Importing the data and the necessary libraries

# %%
from pathlib import Path
input_path=Path().resolve() / 'input'
input_path
# Out:
# PosixPath('/home/ahmed/MyOwnProjects/nlp-python-project/src/input')

# %%
with open (input_path/'Data_1.txt', 'r') as file:
    print(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 from pathlib import Path
#       2 input_path=Path().resolve().parent / 'input'
# ----> 3 with open (input_path/'Data_1.txt', 'r') as file:
#       4     print(file)
#
# File ~/.virtualenvs/crosscompute/lib/python3.11/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ahmed/MyOwnProjects/nlp-python-project/input/Data_1.txt'
